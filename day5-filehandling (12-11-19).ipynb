# %%
f=open("abc.txt","w")

# %%
print("file name: ",f.name)
# Out:
# file name:  abc.txt

# %%
print("file mode:",f.mode)
# Out:
# file mode: w

# %%
f=open("abc.txt","w")
print("file name: ",f.name)
print("file mode:",f.mode)
print("is file readable:",f.readable())
print("is file writable:",f.writable())
print("is file closed:",f.closed)
f.close()
print("is file closed:",f.closed)
# Out:
# file name:  abc.txt
# file mode: w
# is file readable: False
# is file writable: True
# is file closed: False
# is file closed: True

# %%
f=open("abcd.txt","w")
f.write("kotireddy\n")
f.write("pulusu\n")
f.write("veldurthy\n")
print("data writen to the file successfully")
f.close()
# Out:
# data writen to the file successfully

# %%
f=open("ab.txt","w")
f.writelines(["kotireddy pulusu \n"," hyd"])
f.close()

# %%
f=open("ab.txt","r")
data=f.read()
print(data)
f.close()
# Out:
# kotireddy pulusu
#  hyd

# %%
f=open("ab.txt","r")
data=f.read(100)
print(data)
f.close()
# Out:
# kotireddy pulusu
#  hyd

# %%
f=open("ab.txt","r")
line1=f.readline()
print(line1,end="")
line2=f.readline()
print(line2,end="")
line=f.readline()
print(line)
f.close()

# %%
f=open("abcd.txt","r")
lines=f.readlines()
for line in lines[1]:
    print(line,end="")
f.close()
# Out:
# pulusu

# %%
f=open("abcd.txt","a")
f.write("hello wrold")
f.close()

# %% [markdown]
# # with
#  the with statement can be used while opening a file.
#  we can use this to group file operation statements within a block.
#  the advantage of with statements is it will take care closing of file, after completing all operations automatically even in the case of exception also, and we are not required to close explicitly.

# %%
with open("abcd.txt","w") as f:
    f.write("kotireddy\n")
    f.write("hyd\n")
    f.write("jntu")
    print("is file closed:",f.closed)
print("is file close:",f.closed)
# Out:
# is file closed: False
# is file close: True

# %%
f=open("abcd.txt","r")
print(f.tell())
print(f.read(2))
print(f.tell())
print(f.read(3))
print(f.tell())
# Out:
# 0
# ko
# 2
# tir
# 5

# %% [markdown]
# # seek():

# %%
f=open("abcd.txt","r")
print(f.seek(2))
print(f.read(2 .̣.......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................))
# Out:
# 2
# ti
