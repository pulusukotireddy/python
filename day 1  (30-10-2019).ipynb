# %% [markdown]
# # python
#
# ## python
#
# ### python
#
# #### python
# 1. a
# 2. b
#        1.c
#        2.d
# ![image.png](attachment:image.png)

# %% [markdown]
# keywords:
#     1.keywords are total 33 in python
#     2.these are predefined words
#     3.every keyword has different meaning has contain.
#     4.all keywords are contain lowercase
#     5.except these  3 are 1.True
#                           2.False
#                           3.None

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %% [markdown]
# # variables

# %%
x=65
y=25
x+y
type(x)
# Out:
# int

# %% [markdown]
# # input() and print()

# %%
print(x)
# Out:
# 65

# %%
print("hello world")
# Out:
# hello world

# %%
print("the value of x is:",x)
# Out:
# the value of x is: 65

# %% [markdown]
# create 2 variables if the names age and name of the candidate and you need to accept values from user and display the output fallow

# %%
x=input("enter my name:")
y=int(input("enter your age:"))
print("my name is",x,"and my age is",y)
# Out:
# enter my name:kotireddy
# enter your age:22
# my name is kotireddy and my age is 22

# %%
x=input("enter my name:")
y=input("enter my course:")
print("my name is",x,end="")
print("my course is",y)
# Out:
# enter my name:kotireddy
# enter my course:python
# my name is kotireddymy course is python

# %%
x=input("enter my name:")
y=input("enter my course:")
print("my name is",x,"my course is",y,sep="\n")
# Out:
# enter my name:kotireddy
# enter my course:22
# my name is
# kotireddy
# my course is
# 22

# %% [markdown]
# ## indentations

# %% [markdown]
# y=int(input("enter your age:"))
# if y>18:
#     print("candidate is eligible for vote")
#     print("succefull")
#     if y<20:
#         print("y is 19 years")
#     print("bye")
# print("good bye")

# %% [markdown]
# # Data types
# 1. static
# 2. dynamic
#  # python data types
#
#  ## 1.Fundamental
#         A.int
#         B.float
#         C.complex
#         D.boolean
#         E.string
#  ## 2. collection
#          F.list
#          G.tupple
#          H.set
#          I.dict

# %%
x=10
print(x)
print(type(x))
# Out:
# 10
# <class 'int'>

# %%
x=12.5
y=10
z=x+y
print(z)
print(type(z))
# Out:
# 22.5
# <class 'float'>

# %%
i=complex(2)
print(i)
# Out:
# (2+0j)

# %%
i.real
# Out:
# 2.0

# %%
i.imag
# Out:
# 0.0

# %%
12>32
# Out:
# False

# %%
22<45
# Out:
# True

# %% [markdown]
# ## strings

# %%
help("str")
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
x="python is a open source"
y=x.capitalize()
print(y)
# Out:
# Python is a open source

# %%
l="python is DYNAMICALY TYPE"
k=l.casefold()
print(k)
# Out:
# python is dynamicaly type

# %%
m="python is high level programing lang"
m.center(50,"*")
# Out:
# '*******python is high level programing lang*******'

# %%
k="python has internally so many librarys are contain"
k.count("l")
k.count("t")
# Out:
# 3

# %%
h="python is all 0062"
l=h.encode()

# %%
g="wlcome to promize it services"
g.startswith("w")
# Out:
# True

# %%
g="welcome to promize it services"
g.endswith("s",1,29)
# Out:
# False

# %%
f="python\t is\t a\t programer\t friendly\t lang"
f.expandtabs(4)
# Out:
# 'python   is  a   programer   friendly    lang'

# %%
d="Searches the string for a specified value and returns the position of where it was found"
d.find("z")
# Out:
# -1

# %%
n="my name is {name},iam {age}"
n.format(name="kotireddy",age="22")
# Out:
# 'my name is kotireddy,iam 22'

# %%
o="kotireddy4891478"
o.isalnum()
# Out:
# True
